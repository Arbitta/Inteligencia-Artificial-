# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt #from matplotlib import pyplot

# %%
datos = pd.read_csv("datos/whisky.csv") #levantamos el archivo a un dataframe

# %%
datos.describe()

# %%
type(datos)

# %%
type(datos['Precio'])

# %%
serie = datos['Precio']
type(serie.values)

# %%
len(datos)

# %%
datos.shape #dimensión en filas y columnas

# %%
datos.head(10)

# %%
pd.set_option("display.precision",2)#antes de cargar el dataframe

# %%
datos.head()

# %%
datos.tail()#los ultimos 5 elementos

# %%
datos.info()

# %% [markdown]
# # posicionamiento

# %%
datos.loc[4][2]#elemento inicial es 0 ,0

# %%
datos.loc[30]['Precio'] #devuelve el precio del whisky de la posición 30

# %%
datos

# %%
datos.loc[30][:] #comodin que representa todo lo que viene a continuación

# %%
datos.loc[:]['Precio']#todas las filas de la columna precio

# %%
datos['Precio'].value_counts()#cuenta los precios repatidos

# %%
datos['Precio'].min()

# %%
datos['Precio'].agg(("min","max","sum","mean","std"))

# %%
datos.loc[datos['Precio']>80,'Categoria'] #solicito la categoria de los whiskys con precio mayores a 80.

# %%
datos2= datos[(datos['Precio']>80)&(datos['Anejamiento']>10)] #datos['Precio']

# %%
datos2['Malta']

# %%
#manipulación de datos con mas de un dataframe

# %%
nuevoFrame = datos.copy()

# %%
nuevoFrame

# %%
columnas = nuevoFrame.columns.values
columnas

# %%
listaColumna = columnas.tolist() #convierte un array a lista
listaColumna

# %%
for col in listaColumna:
    print(col)

# %%
nuevoFrame['Precio']=30 #asigno a todas las filas el valor precio=30 #nuevoFrame[nuevoFrame['Precio']=30]

# %%
nuevoFrame

# %%
nuevoFrame['Performance']=nuevoFrame['Precio']*nuevoFrame['Calidad']/nuevoFrame['Anejamiento']

# %%
nuevoFrame

# %%
nuevoFrame.drop('Performance',inplace=True,axis=1)

# %%
nuevoFrame

# %%
nuevoFrame.drop('id_Whisky',inplace=True,axis=1)

# %%
nuevoFrame
