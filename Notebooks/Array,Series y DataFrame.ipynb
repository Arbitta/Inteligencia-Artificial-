# %% [markdown]
# # array numpy y series en pandas

# %%
import numpy as np
import pandas as pd

# %%
lista1=[1,2,3]
lista2=[4,5,6]
lista3=[]
for i in range(len(lista1)):
    lista3.append(lista1[i]+lista2[i])
lista3

# %%
x= np.array(lista1)
y=np.array(lista2)
z=x+y
z

# %%
array= np.arange(51)
array

# %%
arrayCeros= np.zeros(5)
arrayCeros

# %%
arrayUnos=np.ones(5)
arrayUnos

# %% [markdown]
# # series

# %%
serie=pd.Series(z)
serie

# %%
serie.index

# %%
array=serie.values
array

# %%
serie.index=['valor1','valor2','valor3']

# %%
serie

# %%
serie['valor1']

# %%
serie[0]

# %% [markdown]
# # dataframe

# %%
data=pd.DataFrame(serie)
data

# %%
data.columns=['precio']
data

# %%
data['precio']

# %%
data['altura']=[56,43,23]

# %%
data

# %%
data.loc[3]=[23,34]
data

# %%
data.index=['valor1','valor2','valor3','valor4']

# %%
data

# %% [markdown]
# convertir una columna a numpy

# %%
arrayNP = data['precio'].values
arrayNP

# %%
array2d=np.array(data[['precio','altura']])

# %%
array2d[1,1]

# %% [markdown]
# crear un dataframe a traves de un diccionario

# %%
nombre_edad ={'Nombre':['Marcos','Juan','Martin'],
              'edad': [32,35,39]
             }
nombre_edad

# %%
frame = pd.DataFrame(nombre_edad)
frame
